# %% [markdown]
# # Visualising Lifting Data

# %% [markdown]
# ## Setup

# %%
from data.dataReader import DataReader
from data.dataHandler import DataHandler
from matplotlib import pyplot as plt
from datetime import datetime

dr = DataReader('data\\data.csv')
dh = DataHandler()
# Out:
# 2020-09-01 13:30:19,524 - DEBUG - cwd: c:\Users\thomas.elder\python-lifting

# %%
squatMaxes = dh.getExerciseMaxes(dr.sessions, 'Back Squat', 3)

plt.scatter([max['date'] for max in squatMaxes], [max['weight'] for max in squatMaxes], color = 'red')
#plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Date vs Weight (Training set)')
plt.xlabel('Date')
plt.ylabel('Weight')
plt.show()
